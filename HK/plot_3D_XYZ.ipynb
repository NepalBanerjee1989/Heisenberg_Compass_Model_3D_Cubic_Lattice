# %%
###################################################################################
# Heisenberg Spin Configuration  #
###################################################################################
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm ,colors
import time
from matplotlib.animation import FuncAnimation
from IPython.display import clear_output
count = 0
while (count < 550):
    #clear_output(wait=True)
    if count==0:
        time.sleep(13)
    else:
        time.sleep(13)
    print('count=',count)    
    count = count + 1

################################################################################### 
    r=1
    pi=np.pi
    cos=np.cos
    sin=np.sin
    phi,theta =np.mgrid[0.0:pi:100j , 0.0:2.0*pi:100j ]

    x=r*sin(phi)*cos(theta)
    y=r*sin(phi)*sin(theta)
    z=r*cos(phi)

    fig = plt.figure(figsize =(8,8))
    #fig=plt.figure()
    ax= fig.add_subplot(221, projection='3d')

#import random initial spin components data 
    data=np.loadtxt('spin_after_transition_1')
    T=data[1,0]
    xx=data[:,4]
    yy=data[:,5]
    zz=data[:,6]

    ax.plot_surface(x,y,z,rstride=1,cstride=1,color='w',alpha=0.6,linewidth=0.1)
    ax.scatter(xx,yy,zz,color="b",s=10)
##############################################
    ax.set_xlim([-1,1])
    ax.set_ylim([-1,1])
    ax.set_zlim([-1,1])

    ax.set_xlabel('$S_x$',fontsize=10)
    ax.set_ylabel('$S_y$',fontsize=10)
    ax.set_zlabel('$S_z$',fontsize=10)

#plt.xticks(fontsize=10)
#plt.yticks(fontsize=10)
#plt.zticks(fontsize=20)
    ax.set_xticks([-1.0,-0.5 ,0, 0.5, 1.0])

    ax.set_yticks([-1.0,-0.5 ,0, 0.5, 1.0])

    ax.set_zticks([-1.0,-0.5 ,0, 0.5, 1.0])

    ax.set_aspect("equal")
    plt.tight_layout()

    plt.title('T='+str(T),fontsize=20) 

 #########################################################    
    if count==1:
        plt.savefig('XY_1.png',bbox_inches = 'tight')
     
    if count==10:
        plt.savefig('XY_2.png',bbox_inches = 'tight')
     
    if count==20:
        plt.savefig('XY_3.png',bbox_inches = 'tight')
    
    if count==30:
        plt.savefig('XY_4.png',bbox_inches = 'tight')
     
    if count==40:
        plt.savefig('XY_5.png',bbox_inches = 'tight')
     
    if count==50:
        plt.savefig('XY_6.png',bbox_inches = 'tight')
     
    if count==60:
        plt.savefig('XY_7.png',bbox_inches = 'tight')
     
    if count==70:
        plt.savefig('XY_8.png',bbox_inches = 'tight')
     
    if count==80:
        plt.savefig('XY_9.png',bbox_inches = 'tight')
    
    if count==90:
        plt.savefig('XY_10.png',bbox_inches = 'tight')
    
    if count==100:
        plt.savefig('XY_11.png',bbox_inches = 'tight')
    
    if count==110:
        plt.savefig('XY_12.png',bbox_inches = 'tight')
    
    if count==120:
        plt.savefig('XY_13.png',bbox_inches = 'tight')
    
    if count==130:
        plt.savefig('XY_14.png',bbox_inches = 'tight')
    
    if count==140:
        plt.savefig('XY_15.png',bbox_inches = 'tight')
    
    if count==150:
        plt.savefig('XY_16.png',bbox_inches = 'tight')
   
    if count==160:
        plt.savefig('XY_17.png',bbox_inches = 'tight')
    
    if count==170:
        plt.savefig('XY_18.png',bbox_inches = 'tight')
    
    if count==180:
        plt.savefig('XY_19.png',bbox_inches = 'tight')
        
    if count==200:
        plt.savefig('XY_20.png',bbox_inches = 'tight')
    
    if count==220:
        plt.savefig('XY_21.png',bbox_inches = 'tight')
     
    if count==240:
        plt.savefig('XY_22.png',bbox_inches = 'tight')
     
    if count==260:
        plt.savefig('XY_23.png',bbox_inches = 'tight')
    
    if count==270:
        plt.savefig('XY_24.png',bbox_inches = 'tight')
   
    if count==280:
        plt.savefig('XY_25.png',bbox_inches = 'tight')
   
    if count==300:
        plt.savefig('XY_26.png',bbox_inches = 'tight')
  
    if count==320:
        plt.savefig('XY_27.png',bbox_inches = 'tight')
    
    if count==340:
        plt.savefig('XY_28.png',bbox_inches = 'tight')
   
    if count==360:
        plt.savefig('XY_29.png',bbox_inches = 'tight')
   
    if count==370:
        plt.savefig('XY_30.png',bbox_inches = 'tight')
    
    if count==380:
        plt.savefig('XY_31.png',bbox_inches = 'tight')
    
    if count==390:
        plt.savefig('XY_32.png',bbox_inches = 'tight')
   
    if count==400:
        plt.savefig('XY_33.png',bbox_inches = 'tight')
   
    if count==420:
        plt.savefig('XY_34.png',bbox_inches = 'tight')
     
    if count==440:
        plt.savefig('XY_35.png',bbox_inches = 'tight')
   
    if count==460:
        plt.savefig('XY_36.png',bbox_inches = 'tight')
   


 #############################################################    
    #print('T=',T)
    #animation = FuncAnimation(fig,interval=2000, repeat = False)
    plt.show()
    
    #plt.draw()
    #plt.pause(0.0000001)
    
    

#############################################
#plt.title('Spin config During Transition')
#ax.set_xlabel('$S_x$')
#ax.set_ylabel('$S_y$')
#ax.set_zlabel('$S_z$')
#print('T=',T)
#plt.show()
#plt.savefig('SPIN_configuration.png')
#############################################
# Out:
# count= 0
# count= 1
# count= 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 17
#      15     time.sleep(13)
#      16 else:
# ---> 17     time.sleep(13)
#      18 print('count=',count)
#      19 count = count + 1
#
# KeyboardInterrupt:
